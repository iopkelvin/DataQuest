# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Reading dataset, with cols as columns, as without missing values**

# %%
titanic = pd.read_csv("train.csv")
cols = ["Survived", "Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked"]
titanic = titanic[cols]
titanic = titanic.dropna()

# %% [markdown]
# **KDE distribution for Age, with shade, and without spines**

# %%
sns.set_style("white")
sns.kdeplot(titanic["Age"], shade = True)
plt.xlabel("Age")
sns.despine(left = True, bottom = True)
plt.show()

# %% [markdown]
# **Grid of plots that displays Age dristribution for each Pclass**

# %%
g = sns.FacetGrid(titanic, col = "Pclass", size = 6)
g.map(plt.kdeplot, "Age", shade = True)
plt.despine(left= True, bottom = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-ac99245ae364> in <module>
#       1 g = sns.FacetGrid(titanic, col = "Pclass", size = 6)
# ----> 2 g.map(plt.kdeplot, "Age", shade = True)
#       3 plt.despine(left= True, bottom = True)
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'kdeplot'
