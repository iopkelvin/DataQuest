# %%
distribution = [0,2,3,3,3,4,13]
mean = sum(distribution)/len(distribution)
mean
# Out:
# 4.0

# %%
center = [True if mean == (sum(range(13))/2) else False]

# %%
above = sum(distribution > mean)
below = sum(distribution < mean)
equal_distances = [True if above == below else False]

# %%
above = 0 
below = 0
for i in distribution:
    if i > mean:
        above += 1
    elif i < mean:
        below += 1
equal_distances = [True if above == below else False]

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
houses = pd.read_csv("AmesHousing_1.txt", sep='\t')
houses.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0    131770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
# ...

# %%
import numpy as np
population = [3, 7, 2]
population_mean = sum(population)/len(population)

# %%
import numpy as np
population = [3, 7, 2]
population_mean = np.mean(population)
sample_means = []
for i in population:
    for j in population:
        sample_means.append((i+j)/2)
sample_means = sum(sample_means)/len(sample_means)        
unbiased = sample_means == population_mean

# %%
unbiased
# Out:
# True

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
houses = pd.read_csv("AmesHousing_1.txt", sep='\t')
houses.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0    131770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
# ...

# %%
houses_per_year = houses.groupby(houses["Yr Sold"])["SalePrice"].agg({'Mean Price':'mean', 'Houses Sold':'count'})
# Out:
# /Users/kelvin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.

# %%
houses_per_year = pd.DataFrame(houses_per_year.head()).reset_index()
houses_per_year
# Out:
#    Yr Sold     Mean Price  Houses Sold
# 0     2006  181761.648000          625
# 1     2007  185138.207493          694
# 2     2008  178841.750804          622
# 3     2009  181404.567901          648
# 4     2010  172597.598240          341

# %%
mean_new = houses_per_year["Mean Price"].mean()
mean_original = sum(houses.SalePrice) / len(houses.SalePrice)
difference = mean_original - mean_new
difference
# Out:
# 847.3055805878539

# %%
houses_per_year["sum_per_year"] = houses_per_year["Mean Price"] * houses_per_year["Houses Sold"]
weighted_mean = houses_per_year["sum_per_year"].sum() / houses_per_year["Houses Sold"].sum()
mean_original = sum(houses["SalePrice"]) / len(houses["SalePrice"])
difference = round(mean_original, 10) - round(weighted_mean, 10)

# %%
houses_per_year
# Out:
#    Yr Sold     Mean Price  Houses Sold  sum_per_year
# 0     2006  181761.648000          625   113601030.0
# 1     2007  185138.207493          694   128485916.0
# 2     2008  178841.750804          622   111239569.0
# 3     2009  181404.567901          648   117550160.0
# 4     2010  172597.598240          341    58855781.0

# %%
for a,b in zip(houses_per_year["Mean Price"], houses_per_year["Houses Sold"]):
    print(a,b)
# Out:
# 181761.648 625
# 185138.2074927954 694
# 178841.7508038585 622
# 181404.56790123458 648
# 172597.5982404692 341

# %%
import numpy as np

def weighted_mean(distribution, weights):
    weighted_sum = []
    for mean, weight in zip(distribution, weights):
        weighted_sum.append(mean * weight)
      
    return sum(weighted_sum) / sum(weights)

weighted_mean_function = weighted_mean(houses_per_year["Mean Price"], houses_per_year["Houses Sold"])

from numpy import average
weighted_mean_numpy = average(houses_per_year["Mean Price"], weights = houses_per_year["Houses Sold"])

equal = round(weighted_mean_function, 10) == round(weighted_mean_numpy, 10)

# %%
houses_per_year["Mean Price"]
# Out:
# 0    181761.648000
# 1    185138.207493
# 2    178841.750804
# 3    181404.567901
# 4    172597.598240
# Name: Mean Price, dtype: float64

# %%
def weighted_mean(distribution, weights):
    weighted_sum = []
    for mean, weight in zip(distribution, weights):
        weighted_sum.append(mean * weight)
    return sum(weighted_sum), su(weights)

# %%
distribution1 = [23, 24, 22, '20 years or lower,', 23, 42, 35]
distribution2 = [55, 38, 123, 40, 71]
distribution3 = [45, 22, 7, '5 books or lower', 32, 65, '100 books or more']

# %%
20, 22, 23, 23, 24, 35, 42
# Out:
# [23, 24, 22, '20 years or lower,', 23, 42, 35]

# %%
values = houses["TotRms AbvGrd"].copy()
sorted_values = values.replace("10 or more", 10).astype(int).sort_values(ascending=True)
median = sorted_values.iloc[int(len(sorted_values)/2)]
# Out:
# 6

# %%
houses
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0    131770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
mean = houses["Overall Cond"].mean()
median = houses["Overall Cond"].median()

# %%
import matplotlib.pyplot as plt
plt.hist(houses["Overall Cond"])
plt.show()

# %%
print(mean)
print(median)
# Out:
# 5.563139931740614
# 5.0

# %%
houses["Land Slope"]
# Out:
# 0       Gtl
# 1       Gtl
# 2       Gtl
# 3       Gtl
# 4       Gtl
#        ...
# 2925    Gtl
# 2926    Mod
# 2927    Gtl
# 2928    Mod
# 2929    Mod
# Name: Land Slope, Length: 2930, dtype: object

# %%
houses["Roof Style"]
# Out:
# 0         Hip
# 1       Gable
# 2         Hip
# 3         Hip
# 4       Gable
#         ...
# 2925    Gable
# 2926    Gable
# 2927    Gable
# 2928    Gable
# 2929    Gable
# Name: Roof Style, Length: 2930, dtype: object

# %%
houses["Kitchen AbvGr"].value_counts()
# Out:
# 1    2796
# 2     129
# 0       3
# 3       2
# Name: Kitchen AbvGr, dtype: int64

# %%
houses["Bedroom AbvGr"].value_counts()
# Out:
# 3    1597
# 2     743
# 4     400
# 1     112
# 5      48
# 6      21
# 0       8
# 8       1
# Name: Bedroom AbvGr, dtype: int64

# %%
houses["SalePrice"].value_counts()
# Out:
# 135000    34
# 140000    33
# 130000    29
# 155000    28
# 145000    26
#           ..
# 256300     1
# 274725     1
# 332200     1
# 57625      1
# 169985     1
# Name: SalePrice, Length: 1032, dtype: int64

# %%
houses.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0    131770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
# ...

# %%
import pandas as pd
houses = pd.read_table('AmesHousing_1.txt')
def function(array):
    return max(array) - min(array)

# %%
dict(houses.groupby("Yr Sold").agg(function)["SalePrice"])
# Out:
# {2006: 590000, 2007: 715700, 2008: 601900, 2009: 575100, 2010: 598868}

# %%
houses.groupby("Yr Sold").agg(function)["SalePrice"].plot()

# %%
C = [1,1,1,1,1,1,1,1,1,21]

# %%
def standard_deviation(array):
    reference_point = sum(array) / len(array)
    
    distances = []
    for value in array:
        squared_distance = (value - reference_point)**2
        distances.append(squared_distance)
        
    variance = sum(distances) / len(distances)
    
    return variance**(1/2)

# %%
houses.groupby("Yr Sold").agg(standard_deviation)["SalePrice"]
# Out:
# Yr Sold
# 2006    82553.575636
# 2007    82483.284333
# 2008    75531.946226
# 2009    80794.390703
# 2010    74521.920712
# Name: SalePrice, dtype: float64

# %%
def standard_deviation(array):
    reference_point = sum(array) / len(array)
    
    distances = []
    for value in array:
        squared_distance = (value - reference_point)**2
        distances.append(squared_distance)
    
    variance = sum(distances) / len(distances)
    
    return np.sqrt(variance)

# %%
import matplotlib.pyplot as plt

deviations = []
for i in range(5000):
    sample = list(houses["SalePrice"].sample(10, random_state=i)
    standard_deviation = standard_deviation(sample)
    deviations.append(standard_deviation)
    
plt.hist(deviations)
plt.axvline(standard_deviation(houses["SalePrice"]))
# Out:
#   File "<ipython-input-118-b84dca69d04c>", line 6
#     standard_deviation = standard_deviation(sample)
#                      ^
# SyntaxError: invalid syntax

# %%
array = list(houses["SalePrice"].sample(10, random_state=i))

# %%
standard_deviation(array)
# Out:
# 62745.99025308311
